# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# 设置随机种子
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
import os

# 数据集路径（根据实际结构修改）
base_dir = r'/home/dingziming/PycharmProjects/AI-Practices/python深度学习红书/深度学习用于文本和序列/处理文本数据/使用词嵌入/imdb数据集/train'
texts = []
labels = []

# 遍历neg和pos子文件夹
for label_type in ['neg', 'pos']:
    dir_name = os.path.join(base_dir, label_type)
    for fname in os.listdir(dir_name):
        if fname.endswith('.txt'):
            # 拼接完整文件路径
            fpath = os.path.join(dir_name, fname)
            # 读取文件内容
            with open(fpath, encoding='utf-8') as f:
                texts.append(f.read())
            # 设置标签：neg为0，pos为1
            labels.append(0 if label_type == 'neg' else 1)

# 文本分词及序列转换
max_words = 10000  # 只考虑前10000个最常见的单词
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(texts)  # 构建词表
sequences = tokenizer.texts_to_sequences(texts)  # 转换为整数序列

# 序列填充，统一长度
maxlen = 100
data = pad_sequences(sequences, maxlen=maxlen)
labels = np.asarray(labels)

# 输出信息验证
print(f'找到 {len(tokenizer.word_index)} 个独特的词汇')
print(f'数据张量形状: {data.shape}')
print(f'标签张量形状: {labels.shape}')

indices = np.arange(data.shape[0])
np.random.shuffle(indices)  # 打乱数据顺序
data = data[indices]
labels = labels[indices]

training_samples = 20000
validation_samples = 5000

x_train = data[:training_samples]
y_train = labels[:training_samples]
x_val = data[training_samples: training_samples + validation_samples]
y_val = labels[training_samples: training_samples + validation_samples]

# 加载GloVe词向量
glove_dir = r"home/dingziming/PycharmProjects/AI-Practices/python深度学习红书/深度学习用于文本和序列/处理文本数据/使用词嵌入/GloVe/glove.840B.300d.txt"

embeddings_index = {}
f = open(os.path.join(glove_dir, 'glove.840B.300d.txt'), encoding='utf-8')
line_count = 0
error_lines = []  # 记录转换失败的行

for line in f:
    line_count += 1
    values = line.split()
    word = values[0]
    try:
        # 尝试将词向量部分转为float32数组
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    except ValueError as e:
        # 捕获转换错误，记录该行
        error_lines.append((line_count, line.strip()))
        print(f"第{line_count}行转换失败: {e}")

f.close()
print(f'共加载 {len(embeddings_index)} 个词向量')

# 打印异常行示例（如果有）
if error_lines:
    print(f"\n共 {len(error_lines)} 行转换失败，前5条示例：")
    for i, (line_num, line_content) in enumerate(error_lines[:5]):
        print(f"第{line_num}行: {line_content}")

# 构建嵌入矩阵
embedding_dim = 300
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in tokenizer.word_index.items():
    if i < max_words:
        embedding_vector = embeddings_index.get(word)  # 这里移除了多余的file:
        if embedding_vector is not None:
            # 如果单词不在GloVe词表中，则保持为0向量
            embedding_matrix[i] = embedding_vector
# Out:
# 找到 88582 个独特的词汇
# 数据张量形状: (25000, 100)
# 标签张量形状: (25000,)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 57
#      54 glove_dir = r"home/dingziming/PycharmProjects/AI-Practices/python深度学习红书/深度学习用于文本和序列/处理文本数据/使用词嵌入/GloVe/glove.840B.300d.txt"
#      56 embeddings_index = {}
# ---> 57 f = open(os.path.join(glove_dir, 'glove.840B.300d.txt'), encoding='utf-8')
#      58 line_count = 0
#      59 error_lines = []  # 记录转换失败的行
#
# File ~/anaconda3/envs/DL-310/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'home/dingziming/PycharmProjects/AI-Practices/python深度学习红书/深度学习用于文本和序列/处理文本数据/使用词嵌入/GloVe/glove.840B.300d.txt/glove.840B.300d.txt'

# %%
# 构建模型
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense

model = Sequential()
model.add(Embedding(max_words,embedding_dim, input_length=maxlen))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 from tensorflow.keras.layers import Embedding, Flatten, Dense
#       5 model = Sequential()
# ----> 6 model.add(Embedding(max_words,embedding_dim, input_length=maxlen))
#       7 model.add(Flatten())
#       8 model.add(Dense(32, activation='relu'))
#
# NameError: name 'embedding_dim' is not defined

# %%
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False  # 冻结嵌入层

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=100, batch_size=200, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 2ms/step - loss: 0.6344 - accuracy: 0.6428 - val_loss: 0.5940 - val_accuracy: 0.7130
# Epoch 2/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4259 - accuracy: 0.8206 - val_loss: 0.4741 - val_accuracy: 0.7766
# Epoch 3/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8819 - val_loss: 0.4865 - val_accuracy: 0.7762
# Epoch 4/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2346 - accuracy: 0.9166 - val_loss: 0.5302 - val_accuracy: 0.7676
# Epoch 5/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1803 - accuracy: 0.9434 - val_loss: 0.5439 - val_accuracy: 0.7712
# Epoch 6/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1341 - accuracy: 0.9658 - val_loss: 0.6110 - val_accuracy: 0.7624
# Epoch 7/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9811 - val_loss: 0.6392 - val_accuracy: 0.7614
# Epoch 8/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0656 - accuracy: 0.9916 - val_loss: 0.6818 - val_accuracy: 0.7604
# Epoch 9/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 0.9978 - val_loss: 0.7206 - val_accuracy: 0.7588
# Epoch 10/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9991 - val_loss: 0.7720 - val_accuracy: 0.7614
# Epoch 11/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0217 - accuracy: 0.9994 - val_loss: 0.8195 - val_accuracy: 0.7626
# Epoch 12/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9995 - val_loss: 0.8471 - val_accuracy: 0.7624
# Epoch 13/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.9995 - val_loss: 0.8709 - val_accuracy: 0.7602
# Epoch 14/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.9995 - val_loss: 0.9001 - val_accuracy: 0.7614
# Epoch 15/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9995 - val_loss: 0.9177 - val_accuracy: 0.7616
# Epoch 16/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9995 - val_loss: 0.9494 - val_accuracy: 0.7628
# Epoch 17/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0049 - accuracy: 0.9995 - val_loss: 0.9691 - val_accuracy: 0.7616
# Epoch 18/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 0.9995 - val_loss: 1.0022 - val_accuracy: 0.7640
# Epoch 19/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 1.0277 - val_accuracy: 0.7620
# Epoch 20/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 1.0399 - val_accuracy: 0.7632
# Epoch 21/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 1.0623 - val_accuracy: 0.7640
# Epoch 22/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 1.0886 - val_accuracy: 0.7636
# Epoch 23/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 1.1061 - val_accuracy: 0.7632
# Epoch 24/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 1.1170 - val_accuracy: 0.7624
# Epoch 25/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 1.1415 - val_accuracy: 0.7632
# Epoch 26/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 1.1592 - val_accuracy: 0.7632
# Epoch 27/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 1.1785 - val_accuracy: 0.7618
# Epoch 28/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 1.1894 - val_accuracy: 0.7628
# Epoch 29/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 1.2043 - val_accuracy: 0.7618
# Epoch 30/100
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 1.2146 - val_accuracy: 0.7612
# Epoch 31/100
# 100/100 [==============================] - 0s 2ms/step - loss: 9.6929e-04 - accuracy: 0.9995 - val_loss: 1.2302 - val_accuracy: 0.7610
# Epoch 32/100
# 100/100 [==============================] - 0s 2ms/step - loss: 9.0896e-04 - accuracy: 0.9995 - val_loss: 1.2441 - val_accuracy: 0.7600
# Epoch 33/100
100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.5510e-04 - accuracy: 1.0000 - val_loss: 1.6720 - val_accuracy: 0.7608
# Epoch 78/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.5159e-04 - accuracy: 1.0000 - val_loss: 1.6770 - val_accuracy: 0.7618
# Epoch 79/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.4811e-04 - accuracy: 1.0000 - val_loss: 1.6851 - val_accuracy: 0.7620
# Epoch 80/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.4447e-04 - accuracy: 1.0000 - val_loss: 1.6924 - val_accuracy: 0.7632
# Epoch 81/100
# 100/100 [==============================] - 0s 1ms/step - loss: 2.4108e-04 - accuracy: 1.0000 - val_loss: 1.6991 - val_accuracy: 0.7622
# Epoch 82/100
# 100/100 [==============================] - 0s 1ms/step - loss: 2.3749e-04 - accuracy: 1.0000 - val_loss: 1.7109 - val_accuracy: 0.7616
# Epoch 83/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.3414e-04 - accuracy: 1.0000 - val_loss: 1.7169 - val_accuracy: 0.7630
# Epoch 84/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.3225e-04 - accuracy: 1.0000 - val_loss: 1.7324 - val_accuracy: 0.7578
# Epoch 85/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.3277e-04 - accuracy: 1.0000 - val_loss: 1.7010 - val_accuracy: 0.7614
# Epoch 86/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.2661e-04 - accuracy: 1.0000 - val_loss: 1.7173 - val_accuracy: 0.7620
# Epoch 87/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.2221e-04 - accuracy: 1.0000 - val_loss: 1.7320 - val_accuracy: 0.7620
# Epoch 88/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.1826e-04 - accuracy: 1.0000 - val_loss: 1.7459 - val_accuracy: 0.7608
# Epoch 89/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.1455e-04 - accuracy: 1.0000 - val_loss: 1.7533 - val_accuracy: 0.7614
# Epoch 90/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.1116e-04 - accuracy: 1.0000 - val_loss: 1.7603 - val_accuracy: 0.7616
# Epoch 91/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.0764e-04 - accuracy: 1.0000 - val_loss: 1.7699 - val_accuracy: 0.7620
# Epoch 92/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.0415e-04 - accuracy: 1.0000 - val_loss: 1.7789 - val_accuracy: 0.7616
# Epoch 93/100
# 100/100 [==============================] - 0s 2ms/step - loss: 2.0088e-04 - accuracy: 1.0000 - val_loss: 1.7873 - val_accuracy: 0.7620
# Epoch 94/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.9749e-04 - accuracy: 1.0000 - val_loss: 1.7977 - val_accuracy: 0.7616
# Epoch 95/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.9418e-04 - accuracy: 1.0000 - val_loss: 1.8002 - val_accuracy: 0.7622
# Epoch 96/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.9088e-04 - accuracy: 1.0000 - val_loss: 1.8067 - val_accuracy: 0.7614
# Epoch 97/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.8758e-04 - accuracy: 1.0000 - val_loss: 1.8158 - val_accuracy: 0.7620
# Epoch 98/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.8436e-04 - accuracy: 1.0000 - val_loss: 1.8236 - val_accuracy: 0.7618
# Epoch 99/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.8103e-04 - accuracy: 1.0000 - val_loss: 1.8302 - val_accuracy: 0.7620
# Epoch 100/100
# 100/100 [==============================] - 0s 2ms/step - loss: 1.7792e-04 - accuracy: 1.0000 - val_loss: 1.8360 - val_accuracy: 0.7620

# %%
model.save(r'C:\Users\Administrator\PycharmProjects\深度学习日常练习项目\python深度学习红书\深度学习用于文本和序列\处理文本数据\使用词嵌入\训练好的imdb模型\pre_trained_glove_model.h5')

# %%
# 绘制结果
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
model.load_weights(r'C:\Users\Administrator\PycharmProjects\深度学习日常练习项目\python深度学习红书\深度学习用于文本和序列\处理文本数据\使用词嵌入\训练好的imdb模型\pre_trained_glove_model.h5')

# %%
model.evaluate(x_val, y_val)
# Out:
# 157/157 [==============================] - 0s 1ms/step - loss: 1.8360 - accuracy: 0.7620
# [1.8359546661376953, 0.7620000243186951]
