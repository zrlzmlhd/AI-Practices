# %%
# 如果验证损失不在降低 则降低学习率
callbacks_list = [
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=10
    )
]

model.fit(x,y,
          epochs=10,
          callbacks = callbacks_list,
          validation_data=(x_val, y_val))
