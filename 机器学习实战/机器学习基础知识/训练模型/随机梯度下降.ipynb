# %%
import numpy as np

# 设置随机种子
np.random.seed(42)
m = 100 # 训练样本总数
n_epochs = 50 # 进行50次迭代
t0, t1 = 5, 50 # t0是学习率的初始值，t1是学习率衰减的步长 也就是衰减的速度

def learning_schedule(t):
    return t0 / (t + t1)

# 随机初始化
theta = np.random.randn(2,1)

for epoch in range(n_epochs):
    for i in range(m):
        random_index = np.random.randint(m) # 随机获取一个索引
        xi = X_b[random_index:random_index+1] # 获取样本
        yi = y[random_index:random_index+1] # 获取标签
        gradients = 2 * xi.T.dot(xi.dot(theta) - yi) # 计算梯度
        eta = learning_schedule(epoch * m + i) # 降低学习率
        theta = theta - eta * gradients # 更新参数

# %%
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor(max_iter= 1000, tol= 1e-3, penalty= None, eta0= 0.1)
sgd_reg.fit(X, y.ravel())
