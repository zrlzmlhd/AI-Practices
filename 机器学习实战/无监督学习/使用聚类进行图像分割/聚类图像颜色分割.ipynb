# %%
from matplotlib.image import imread
import os

from sklearn.cluster import KMeans

image = imread(os.path.join("images", "unsupervised_learning", "lady_bug.png"))
image.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from matplotlib.image import imread
#       2 import os
# ----> 3 image = imread(os.path.join("images", "unsupervised_learning", "lady_bug.png"))
#       4 image.shape
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\matplotlib\image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
#    1516         "Please open the URL for reading and pass the "
#    1517         "result to Pillow, e.g. with "
#    1518         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1519         )
# -> 1520 with img_open(fname) as image:
#    1521     return (_pil_png_to_float_array(image)
#    1522             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1523             pil_to_array(image))
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\PIL\ImageFile.py:135, in ImageFile.__init__(self, fp, filename)
#     131 self.decodermaxblock = MAXBLOCK
#     133 if is_path(fp):
#     134     # filename
# --> 135     self.fp = open(fp, "rb")
#     136     self.filename = os.fspath(fp)
#     137     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images\\unsupervised_learning\\lady_bug.png'

# %%
X = image.reshape(-1, 3)
kmeans = KMeans(n_clusters= 8).fit(X)
segmented_img = kmeans.cluster_centers_[kmeans.labels_]
segmented_img = segmented_img.reshape(image.shape)
