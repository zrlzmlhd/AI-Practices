# %%
import tensorflow as tf
with tf.io.TFRecordWriter('my_data_tfrecord') as f:
    f.write(b"This is the first record")
    f.write(b"And this is the second record")

filepath = ['my_data.tfrecord']
dataset = tf.data.TFRecordDataset(filepath)
for item in dataset:
    print(item)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[2], line 8
#       6 filepath = ['my_data.tfrecord']
#       7 dataset = tf.data.TFRecordDataset(filepath)
# ----> 8 for item in dataset:
#       9     print(item)
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:766, in OwnedIterator.__next__(self)
#     764 def __next__(self):
#     765   try:
# --> 766     return self._next_internal()
#     767   except errors.OutOfRangeError:
#     768     raise StopIteration
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:749, in OwnedIterator._next_internal(self)
#     746 # TODO(b/77291417): This runs in sync mode as iterators use an error status
#     747 # to communicate that there is no more data to iterate over.
#     748 with context.execution_mode(context.SYNC):
# --> 749   ret = gen_dataset_ops.iterator_get_next(
#     750       self._iterator_resource,
#     751       output_types=self._flat_output_types,
#     752       output_shapes=self._flat_output_shapes)
#     754   try:
#     755     # Fast path for the case `self._structure` is not a nested structure.
#     756     return self._element_spec._from_compatible_tensor_list(ret)  # pylint: disable=protected-access
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3016, in iterator_get_next(iterator, output_types, output_shapes, name)
#    3014   return _result
#    3015 except _core._NotOkStatusException as e:
# -> 3016   _ops.raise_from_not_ok_status(e, name)
#    3017 except _core._FallbackException:
#    3018   pass
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\tensorflow\python\framework\ops.py:7209, in raise_from_not_ok_status(e, name)
#    7207 def raise_from_not_ok_status(e, name):
#    7208   e.message += (" name: " + name if name is not None else "")
# -> 7209   raise core._status_to_exception(e) from None
#
# NotFoundError: {{function_node __wrapped__IteratorGetNext_output_types_1_device_/job:localhost/replica:0/task:0/device:CPU:0}} NewRandomAccessFile failed to Create/Open: my_data.tfrecord : 系统找不到指定的文件。
# ; No such file or directory [Op:IteratorGetNext]

# %% [markdown]
# ## 13.2.1 压缩的TFRecord文件

# %%
# 在需要网络链接加载数据的时候 解压TFRecord很有用
options= tf.io.TFRecordOptions(compression_type= "GZIP")
with tf.io.TFRecordWriter("my_compressed.tfrecord", options=options) as f:
    f.write(b"This is the first record")
    f.write(b"And this is the second record")
dataset = tf.data.TFRecordDataset(['my_compressed.tfrecord'],
                                  compression_type= 'GZIP')

# %% [markdown]
# ## 13.2.2协议缓冲区简介
