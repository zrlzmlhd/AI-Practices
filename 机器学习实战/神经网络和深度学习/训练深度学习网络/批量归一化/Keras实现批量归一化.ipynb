# %%
import tensorflow as tf
from tensorflow import keras

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, activation='elu', kernel_initializer= 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(300, activation='elu', kernel_initializer= 'he_normal'),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  batch_normalization_1 (Batc  (None, 784)              3136
#  hNormalization)
#
#  dense (Dense)               (None, 300)               235500
#
#  batch_normalization_2 (Batc  (None, 300)              1200
#  hNormalization)
#
#  dense_1 (Dense)             (None, 300)               90300
#
#  batch_normalization_3 (Batc  (None, 300)              1200
#  hNormalization)
#
#  dense_2 (Dense)             (None, 10)                3010
#
# =================================================================
# Total params: 334,346
# Trainable params: 331,578
# Non-trainable params: 2,768
# _________________________________________________________________

# %%
# 查看第一个BN层的参数
[(var.name, var.trainable) for var in model.layers[1].variables]
# Out:
# [('batch_normalization_1/gamma:0', True),
#  ('batch_normalization_1/beta:0', True),
#  ('batch_normalization_1/moving_mean:0', False),
#  ('batch_normalization_1/moving_variance:0', False)]

# %%
model.layers[1].updatesn
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_9756\3646448985.py:1: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   model.layers[1].updates
# []

# %% [markdown]
# # 在激活函数之前使用BN层

# %%
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.BatchNormalization(),
    # Dense 层不使用 bias（因为后续有 BN）让BN来做偏移的工作 避免参数冗余
    keras.layers.Dense(300, kernel_initializer='he_normal', use_bias=False),
    keras.layers.BatchNormalization(),
    # 激活函数单独作为一层
    keras.layers.Activation('elu'),
    # 重复上述逻辑：Dense（无 bias）→ BN → 激活
    keras.layers.Dense(300, kernel_initializer='he_normal', use_bias=False),
    keras.layers.BatchNormalization(),
    keras.layers.Activation('elu'),
    keras.layers.Dense(10, activation='softmax')
])
