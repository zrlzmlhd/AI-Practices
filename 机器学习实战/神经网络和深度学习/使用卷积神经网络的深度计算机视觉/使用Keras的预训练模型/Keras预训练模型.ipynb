# %%
import tensorflow as tf
model = keras.applications.ResNet50(weights= "imagenet")

images_resized = tf.image.resize(images, [224, 224])

inputs = keras.applications.resnet50.preprocess_input(images_resized * 255)
# Out:
# C:\Users\Administrator\anaconda3\envs\DeepLearning-py310\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 9s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       6 # 要使用这个预训练模型 要保证输入数据的格式应该是224*224的
#       7 model = keras.applications.ResNet50(weights= "imagenet")
# ----> 9 images_resized = tf.image.resize(images, [224, 224])
#      11 inputs = keras.applications.resnet50.preprocess_input(images_resized * 255)
#      12 # 划分数据集
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\envs\DeepLearning-py310\lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Attempt to convert a value (<module 'keras.api._v2.keras.datasets.fashion_mnist' from 'C:\\Users\\Administrator\\anaconda3\\envs\\DeepLearning-py310\\lib\\site-packages\\keras\\api\\_v2\\keras\\datasets\\fashion_mnist\\__init__.py'>) with an unsupported type (<class 'module'>) to a Tensor.
