# %% [markdown]
# # src - _check_not_on_kaggle_

# %% [markdown]
# ## Notebook运行提示
# - 代码拆分为多个小单元, 便于逐步运行和检查。
# - Notebook 会尽量保持原脚本的注释, 方便理解核心算法与数据处理步骤。
# - 若脚本依赖 `__file__`, 已自动注入路径解析逻辑。

# %% [markdown]
# 该模块为空, 可在此Notebook中添加实现或说明。
